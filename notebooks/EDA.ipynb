# %% [markdown]
# # Análisis exploratorio de anuncios de autos

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../vehicles_us.csv')
df.info()

# %%
px.histogram(df, x='odometer')

# %%
px.scatter(df, x='model_year', y='price')
